# %% [markdown]
# <a href="https://colab.research.google.com/github/Martin26H/-Visualizacion-de-Datos-con-Matplotlib-y-Seaborn/blob/master/Relation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
tips = sns.load_dataset('tips')
tips.head(2)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3

# %%
sns.scatterplot(data= tips, x= 'total_bill', y = 'tip', hue= 'day',style='time',size='size',);
plt.legend(loc='center', bbox_to_anchor=(1.2,0.5))
plt.show()

# %%
sns.lineplot(data= tips, x= 'total_bill', y = 'tip')
plt.show()

# %%
sns.relplot(data= tips, x= 'total_bill', y = 'tip', hue= 'day',style='time',size='size')
plt.show()
