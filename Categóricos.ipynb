# %% [markdown]
# <a href="https://colab.research.google.com/github/Martin26H/-Visualizacion-de-Datos-con-Matplotlib-y-Seaborn/blob/master/Categ%C3%B3ricos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
tips = sns.load_dataset('tips')
tips.head(2)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3

# %%
sns.countplot(data = tips, x= 'day', hue='sex')

# %%
sns.stripplot(data = tips, x= 'day',y='total_bill', hue='sex',dodge=True)
plt.show()

# %%
sns.swarmplot(data = tips, x= 'day',y='total_bill', hue='sex',dodge=True)
plt.show()

# %%
sns.catplot(data = tips, x= 'day',y='total_bill', hue='sex')
plt.show()
