# %% [markdown]
# <a href="https://colab.research.google.com/github/Martin26H/-Visualizaci-n-de-Datos-con-Matplotlib-y-Seaborn/blob/master/orientado_a_objetos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.linspace(0,5,11)
y = x ** 2

# %%
fig = plt.figure()
axes = fig.add_axes([0.1, 0.1,0.5,0.9])
axes.plot(x,y, 'r')

# %%
fig = plt.figure()
axes = fig.add_axes([0.1, 0.1,0.8,0.9])
axes2 = fig.add_axes([0.2, 0.5,0.4,0.3])
axes.plot(x,y, 'r')
axes2.plot(y,x, 'b')
axes2.set_facecolor('gray')

fig.show()
